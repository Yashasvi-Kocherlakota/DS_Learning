# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashasvi-Kocherlakota/DS_Learning/blob/main/TestDome_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/electionpoll.csv')

# %%
df.head(20)
# Out:
#    Date \ Party  National Party  People's Party  Alliance Party  Civic Party  \
# 0    2019-01-01               0              20              27           26
# 1    2019-01-02               0              19              28           26
# 2    2019-01-03               0              20              29           27
# 3    2019-01-04               0              22              25           25
# 4    2019-01-05               0              24              22           21
# 5    2019-01-06               1              24              23           21
# 6    2019-01-07               0              24              25           25
# 7    2019-01-08               0              21              25           22
# 8    2019-01-09               0              21              28           26
# 9    2019-01-10               0              23              24           21
# 10   2019-01-11               0              21              26           26
# ...

# %%
df.describe()
# Out:
#        National Party  People's Party  Alliance Party  Civic Party  \
# count      365.000000      365.000000      365.000000   365.000000
# mean         1.789041        8.145205       19.638356    27.391781
# std          4.499315        8.240763        6.351054     3.901597
# min          0.000000        0.000000        2.000000    18.000000
# 25%          0.000000        1.000000       17.000000    24.000000
# 50%          0.000000        3.000000       21.000000    27.000000
# 75%          0.000000       16.000000       24.000000    30.000000
# max         18.000000       24.000000       36.000000    37.000000
#
#        Conservative Party  Liberal Party  Workers' Party
# count          365.000000     365.000000      365.000000
# mean             2.263014      12.087671       28.684932
# std              1.648135       8.768261        3.790085
# min              0.000000       0.000000       14.000000
# 25%              1.000000       3.000000       26.000000
# ...

# %%
df["Workers' Party"].median()
# Out:
# 29.0

# %%
df['Date \ Party'] = pd.to_datetime(df['Date \ Party'], format='%Y-%m-%d')

# %%
march_data = df[df['Date \ Party'].dt.month == 3]

# %%
difference = march_data["Workers' Party"].max() - march_data["Workers' Party"].min()

# %%
print("Difference (max - min) in March:", difference)
# Out:
# Difference (max - min) in March: 9

# %%
df[df['Civic Party'] == 37]['Date \ Party']
# Out:
# 352   2019-12-19
# Name: Date \ Party, dtype: datetime64[ns]

# %%
df.select_dtypes(include='number').apply(lambda col: col.max() - col.min())
# Out:
# National Party        18
# People's Party        24
# Alliance Party        34
# Civic Party           19
# Conservative Party     6
# Liberal Party         29
# Workers' Party        22
# dtype: int64
